# %% [markdown]
# # Image Classification Using Image Embeddings

# %%
# Load three CSV files
import pandas as pd
image_features_train = pd.read_csv('data/image_features_train.csv')
image_features_val = pd.read_csv('data/image_features_val.csv')
image_features_test = pd.read_csv('data/image_features_test.csv')
print(f"Train shape: {image_features_train.shape}, Val shape: {image_features_val.shape}, Test shape: {image_features_test.shape}")

# %%
# Merge training and validation sets
image_features_train_val = pd.concat([image_features_train, image_features_val], ignore_index=True)

# Extract columns: label, f0, f1, ..., f1151
X_train = image_features_train_val.iloc[:, 3:].values
y_train = image_features_train_val['label'].values

X_test = image_features_test.iloc[:, 3:].values
y_test = image_features_test['label'].values

# Model image features and labels using ML classifiers

# %% [markdown]
# Model image features and labels using ML classifiers

# %% [markdown]
# ## 1 Logistic Regression

# %%
# Logistic Regression
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score

model = LogisticRegression(max_iter=1000, random_state=42)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
acc = accuracy_score(y_test, y_pred)
print(f'Test Accuracy: {acc:.4f}')
print("Logistic Regression Classification Report:")
print(classification_report(y_test, y_pred))

# %% [markdown]
# ## 2 K-Nearest Neighbors (KNN)

# %%
# KNN
from sklearn.neighbors import KNeighborsClassifier
knn_model = KNeighborsClassifier(n_neighbors=5)
knn_model.fit(X_train, y_train)
y_pred_knn = knn_model.predict(X_test)
acc = accuracy_score(y_test, y_pred_knn)
print(f'Test Accuracy: {acc:.4f}')
print("KNN Classification Report:")
print(classification_report(y_test, y_pred_knn))

# %% [markdown]
# ## 3 Random Forest

# %%
# Random Forest
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)
y_pred_rf = rf_model.predict(X_test)
acc = accuracy_score(y_test, y_pred_rf)
print(f'Test Accuracy: {acc:.4f}')
print("Random Forest Classification Report:")
print(classification_report(y_test, y_pred_rf))

# %% [markdown]
# ## 4 Support Vector Machine (SVM)

# %%
# SVM
from sklearn.svm import SVC
svm_model = SVC(kernel='linear', random_state=42)
svm_model.fit(X_train, y_train)
y_pred_svm = svm_model.predict(X_test)
acc = accuracy_score(y_test, y_pred_svm)
print(f'Test Accuracy: {acc:.4f}')
print("SVM Classification Report:")
print(classification_report(y_test, y_pred_svm))

# %% [markdown]
# ## 5 XGBoost

# %%
# XGBoost
from xgboost import XGBClassifier
xgb_model = XGBClassifier(eval_metric='mlogloss', random_state=42)
xgb_model.fit(X_train, y_train)
y_pred_xgb = xgb_model.predict(X_test)
acc = accuracy_score(y_test, y_pred_xgb)
print(f'Test Accuracy: {acc:.4f}')
print("XGBoost Classification Report:")
print(classification_report(y_test, y_pred_xgb))

# %% [markdown]
# ## 6 Multi-Layer Perceptron (MLP)

# %%
# MLP
from sklearn.neural_network import MLPClassifier
mlp_model = MLPClassifier(hidden_layer_sizes=(100,), max_iter=500, random_state=42)
mlp_model.fit(X_train, y_train)
y_pred_mlp = mlp_model.predict(X_test)
acc = accuracy_score(y_test, y_pred_mlp)
print(f'Test Accuracy: {acc:.4f}')
print("MLP Classification Report:")
print(classification_report(y_test, y_pred_mlp))
